# %%
import pandas as pd
import requests
import os

# %%
# Load CSV with logo URLs
csv_path = "dataset/logos_with_urls.csv"
df = pd.read_csv(csv_path)

# Create a folder to store images
output_folder = "logos"
os.makedirs(output_folder, exist_ok=True)

# %%
# Function to download logos, checking if they already exist
def download_logo(row):
    domain = row["domain"].replace(".", "_")  # Replace dots with underscores for filenames
    logo_path = os.path.join(output_folder, f"{domain}.png")

    # If logo already exists, skip downloading
    if os.path.exists(logo_path):
        print(f"✅ {domain}: Logo already exists, skipping download.")
        return logo_path  # Return existing file path

    # Define Clearbit and Google Favicon URLs
    clearbit_url = f"https://logo.clearbit.com/{row['domain']}"
    google_favicon_url = f"https://www.google.com/s2/favicons?domain={row['domain']}&sz=128"

    # Try downloading from Clearbit
    try:
        response = requests.get(clearbit_url, timeout=5)
        if response.status_code == 200:
            with open(logo_path, "wb") as file:
                file.write(response.content)
            print(f"✅ {domain}: Downloaded from Clearbit")
            return logo_path  # Return saved file path
        else:
            print(f"⚠️ {domain}: Clearbit 404, trying Google Favicon...")
    except requests.RequestException as e:
        print(f"❌ {domain}: Clearbit error - {e}")

    # Try downloading from Google Favicon as fallback
    try:
        response = requests.get(google_favicon_url, timeout=5)
        if response.status_code == 200:
            with open(logo_path, "wb") as file:
                file.write(response.content)
            print(f"✅ {domain}: Downloaded from Google Favicon")
            return logo_path
        else:
            print(f"❌ {domain}: No logo found on Google Favicon")
    except requests.RequestException as e:
        print(f"❌ {domain}: Google Favicon error - {e}")

    return None  # Return None if both attempts fail

# Download all logos and store paths
df["saved_path"] = df.apply(download_logo, axis=1)

# Save updated CSV with file paths
df.to_csv("dataset/logos_with_paths.csv", index=False)

print("\n🎉 ✅ All logos processed! Check 'logos_with_paths.csv' for results.")
# Out:
# ✅ stanbicbank_co_zw: Downloaded from Clearbit
# ✅ astrazeneca_ua: Downloaded from Clearbit
# ✅ autosecuritas-ct-seysses_fr: Downloaded from Clearbit
# ✅ ovb_ro: Downloaded from Clearbit
# ✅ mazda-autohaus-hellwig-hoyerswerda_de: Downloaded from Clearbit
# ✅ toyota-buchreiter-eisenstadt_at: Downloaded from Clearbit
# ✅ ebay_cn: Downloaded from Clearbit
# ✅ greatplacetowork_com_bo: Downloaded from Clearbit
# ✅ wurth-international_com: Downloaded from Clearbit
# ⚠️ plameco-hannover_de: Clearbit 404, trying Google Favicon...
# ✅ plameco-hannover_de: Downloaded from Google Favicon
# ⚠️ kia-moeller-wunstorf_de: Clearbit 404, trying Google Favicon...
# ✅ kia-moeller-wunstorf_de: Downloaded from Google Favicon
# ✅ ccusa_co_nz: Downloaded from Clearbit
# ✅ tupperware_at: Downloaded from Clearbit
# ⚠️ zalando_cz: Clearbit 404, trying Google Favicon...
# ✅ zalando_cz: Downloaded from Google Favicon
# ⚠️ crocs_com_uy: Clearbit 404, trying Google Favicon...
# ✅ crocs_com_uy: Downloaded from Google Favicon
# ✅ ymcasteuben_org: Downloaded from Clearbit
# ✅ engie_co_uk: Downloaded from Clearbit
# ⚠️ ibc-solar_jp: Clearbit 404, trying Google Favicon...
# ✅ ibc-solar_jp: Downloaded from Google Favicon
# ✅ lidl_com_cy: Downloaded from Clearbit
# ✅ nobleprog_mx: Downloaded from Clearbit
# ✅ freseniusmedicalcare_ca: Downloaded from Clearbit
# ✅ synlab_com_tr: Downloaded from Clearbit
# ✅ avis_cr: Downloaded from Clearbit
# ⚠️ ebayglobalshipping_com: Clearbit 404, trying Google Favicon...
# ✅ ebayglobalshipping_com: Downloaded from Google Favicon
# ✅ cafelasmargaritas_es: Downloaded from Clearbit
# ✅ affidea_ba: Downloaded from Clearbit
# ✅ bakertilly_lu: Downloaded from Clearbit
# ⚠️ spitex-wasseramt_ch: Clearbit 404, trying Google Favicon...
# ✅ spitex-wasseramt_ch: Downloaded from Google Favicon
# ✅ aamcoanaheim_net: Downloaded from Clearbit
# ✅ deheus_com_vn: Downloaded from Clearbit
# ⚠️ veolia_com_ru: Clearbit 404, trying Google Favicon...
# ✅ veolia_com_ru: Downloaded from Google Favicon
# ✅ julis-sh_de: Downloaded from Clearbit
# ✅ aamcoconyersga_com: Downloaded from Clearbit
# ✅ renault-tortosa_es: Downloaded from Clearbit
# ✅ oil-testing_de: Downloaded from Clearbit
# ✅ baywa-re_es: Downloaded from Clearbit
# ✅ menschenfuermenschen_at: Downloaded from Clearbit
# ✅ europa-union-sachsen-anhalt_de: Downloaded from Clearbit
# ✅ wurthsaudi_com: Downloaded from Clearbit
# ✅ pirtek_be: Downloaded from Clearbit
# ✅ aamcoseguin_com: Downloaded from Clearbit
# ✅ bakertilly_es: Downloaded from Clearbit
# ✅ mazda-autohaus-kaschmieder-waren_de: Downloaded from Clearbit
# ✅ zkteco_vn: Downloaded from Clearbit
# ✅ allianz_nl: Downloaded from Clearbit
# ⚠️ xella-colloquium_berlin: Clearbit 404, trying Google Favicon...
# ✅ xella-colloquium_berlin: Downloaded from Google Favicon
# ✅ unicharm_com_br: Downloaded from Clearbit
# ✅ berlitz-augsburg_de: Downloaded from Clearbit
# ✅ intertongn_es: Downloaded from Clearbit
# ⚠️ bmw-motorrad-euromotos-lyon_fr: Clearbit 404, trying Google Favicon...
# ✅ bmw-motorrad-euromotos-lyon_fr: Downloaded from Google Favicon
# ✅ rsmpoland_pl: Downloaded from Clearbit
# ✅ esseskincare_sg: Downloaded from Clearbit
# ✅ secureparkinghi_com: Downloaded from Clearbit
# ✅ trinkgutlippstadt_de: Downloaded from Clearbit
# ⚠️ bauder_lt: Clearbit 404, trying Google Favicon...
# ✅ bauder_lt: Downloaded from Google Favicon
# ✅ savethechildren_ca: Downloaded from Clearbit
# ✅ mazda-autohaus-lackmann-sendenhorst_de: Downloaded from Clearbit
# ✅ avoncameroun_com: Downloaded from Clearbit
# ✅ menicon_de: Downloaded from Clearbit
# ✅ linde-gas_fi: Downloaded from Clearbit
# ✅ mateco_nl: Downloaded from Clearbit
# ✅ svnefird_com: Downloaded from Clearbit
# ✅ svntrinity_com: Downloaded from Clearbit
# ✅ orient-food_sk: Downloaded from Clearbit
# ✅ noiseassessments_org: Downloaded from Clearbit
# ✅ equans_hu: Downloaded from Clearbit
# ✅ williamblairfunds_com: Downloaded from Clearbit
# ✅ mazdaofamarillo_com: Downloaded from Clearbit
# ✅ mazda-autohaus-roessel-birkenau_de: Downloaded from Clearbit
# ✅ aamcodelran_com: Downloaded from Clearbit
# ✅ mazda-poznan-voyager_pl: Downloaded from Clearbit
# ✅ kapanfastigheter_se: Downloaded from Clearbit
# ⚠️ mazda-autohaus-wassing-ahaus-wuellen_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-wassing-ahaus-wuellen_de: Downloaded from Google Favicon
# ✅ rheine_schule: Downloaded from Clearbit
# ⚠️ ford_pl_ua: Clearbit 404, trying Google Favicon...
# ✅ ford_pl_ua: Downloaded from Google Favicon
# ✅ bioderma_co_za: Downloaded from Clearbit
# ✅ linexps_com: Downloaded from Clearbit
# ✅ kalyanmachines_com: Downloaded from Clearbit
# ✅ kia-suedmobile-radolfzell_de: Downloaded from Clearbit
# ✅ worldvision_ca: Downloaded from Clearbit
# ✅ linde-gas_at: Downloaded from Clearbit
# ✅ renaultsanzhispano_es: Downloaded from Clearbit
# ✅ avia_ch: Downloaded from Clearbit
# ✅ cdviberica_com: Downloaded from Clearbit
# ⚠️ adecco_cl: Clearbit 404, trying Google Favicon...
# ✅ adecco_cl: Downloaded from Google Favicon
# ✅ wurth_co: Downloaded from Clearbit
# ✅ nestle_com_vn: Downloaded from Clearbit
# ✅ daikin_ge: Downloaded from Clearbit
# ✅ ibc-solar_pl: Downloaded from Clearbit
# ✅ toyotanatas_com_tr: Downloaded from Clearbit
# ✅ mazda-autohaus-henseler-schwedt_de: Downloaded from Clearbit
# ⚠️ aamcobloomfield_com: Clearbit 404, trying Google Favicon...
# ✅ aamcobloomfield_com: Downloaded from Google Favicon
# ✅ zalando_dk: Downloaded from Clearbit
# ✅ mazda_de: Downloaded from Clearbit
# ✅ crocs_co_id: Downloaded from Clearbit
# ✅ daikinkuwait_com: Downloaded from Clearbit
# ⚠️ bbraun_rs: Clearbit 404, trying Google Favicon...
# ✅ bbraun_rs: Downloaded from Google Favicon
# ✅ daikin_com_sg: Downloaded from Clearbit
# ✅ aamcosalemor_com: Downloaded from Clearbit
# ✅ spitex-regionbirs_ch: Downloaded from Clearbit
# ✅ mazda-autohaus-hansmann-kassel_de: Downloaded from Clearbit
# ✅ einhell_ba: Downloaded from Clearbit
# ✅ linexofschererville_com: Downloaded from Clearbit
# ✅ webster_nl: Downloaded from Clearbit
# ✅ flashbay_ca: Downloaded from Clearbit
# ✅ pingusenglish_com_tr: Downloaded from Clearbit
# ✅ compo_de: Downloaded from Clearbit
# ✅ aamcowilliamsportpa_com: Downloaded from Clearbit
# ✅ pkf-hk_com: Downloaded from Clearbit
# ⚠️ linde-electronics_com: Clearbit 404, trying Google Favicon...
# ✅ linde-electronics_com: Downloaded from Google Favicon
# ✅ pingusenglish_com_tr: Logo already exists, skipping download.
# ✅ besins-healthcare_se: Downloaded from Clearbit
# ✅ subaru_jp: Downloaded from Clearbit
# ✅ renaultmerida_com_mx: Downloaded from Clearbit
# ⚠️ cvjm-pfalz_de: Clearbit 404, trying Google Favicon...
# ✅ cvjm-pfalz_de: Downloaded from Google Favicon
# ✅ medef-alsace_com: Downloaded from Clearbit
# ✅ allianz-kuhlemann_de: Downloaded from Clearbit
# ✅ tbwa_co_za: Downloaded from Clearbit
# ✅ veolia_fr: Downloaded from Clearbit
# ✅ engie_pt: Downloaded from Clearbit
# ⚠️ subaru_nc: Clearbit 404, trying Google Favicon...
# ✅ subaru_nc: Downloaded from Google Favicon
# ✅ peugeot_sk: Downloaded from Clearbit
# ✅ siebtechnik-tema_cn: Downloaded from Clearbit
# ✅ santillana_com_hn: Downloaded from Clearbit
# ✅ intersport-rent_fr: Downloaded from Clearbit
# ✅ mazdabali_co_id: Downloaded from Clearbit
# ✅ rsmthailand_com: Downloaded from Clearbit
# ⚠️ spitex-wiggertal_ch: Clearbit 404, trying Google Favicon...
# ✅ spitex-wiggertal_ch: Downloaded from Google Favicon
# ✅ aamcocatonsvillemd_com: Downloaded from Clearbit
# ✅ strabag-pfs_com: Downloaded from Clearbit
# ⚠️ autosecuritas-barlin_fr: Clearbit 404, trying Google Favicon...
# ✅ autosecuritas-barlin_fr: Downloaded from Google Favicon
# ✅ aamco-councilbluffs_com: Downloaded from Clearbit
# ✅ meggle-bakery_com: Downloaded from Clearbit
# ✅ nutriciababy_be: Downloaded from Clearbit
# ✅ pcllawyersfrankston_com_au: Downloaded from Clearbit
# ✅ adra_org_pe: Downloaded from Clearbit
# ✅ nestle_ch: Downloaded from Clearbit
# ⚠️ mazda-autohaus-sturne-rochlitz_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-sturne-rochlitz_de: Downloaded from Google Favicon
# ✅ inductotherm_co_kr: Downloaded from Clearbit
# ✅ adecco_cl: Logo already exists, skipping download.
# ✅ renault_dk: Downloaded from Clearbit
# ✅ wurth_com_uy: Downloaded from Clearbit
# ⚠️ renaultchiva_com: Clearbit 404, trying Google Favicon...
# ✅ renaultchiva_com: Downloaded from Google Favicon
# ✅ culliganwi_com: Downloaded from Clearbit
# ⚠️ mazda-autohaus-blank-dinkelsbuehl_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-blank-dinkelsbuehl_de: Downloaded from Google Favicon
# ✅ veolia_ca: Downloaded from Clearbit
# ✅ vitalimages_com: Downloaded from Clearbit
# ✅ amnesty_is: Downloaded from Clearbit
# ✅ meggle_co_jp: Downloaded from Clearbit
# ✅ engie_cl: Downloaded from Clearbit
# ✅ linde-finance_com: Downloaded from Clearbit
# ✅ linde_pe: Downloaded from Clearbit
# ✅ narscosmetics_es: Downloaded from Clearbit
# ✅ brother_com_pe: Downloaded from Clearbit
# ✅ renaultrycauto_es: Downloaded from Clearbit
# ⚠️ kia-gorny-eislingen_de: Clearbit 404, trying Google Favicon...
# ✅ kia-gorny-eislingen_de: Downloaded from Google Favicon
# ✅ ikea_com_hk: Downloaded from Clearbit
# ✅ mazda-autohaus-becker-homburg-bruchhof_de: Downloaded from Clearbit
# ✅ catsprotectionshop_co_uk: Downloaded from Clearbit
# ✅ culliganheartland_com: Downloaded from Clearbit
# ✅ wurth-international_com_cn: Downloaded from Clearbit
# ✅ medef-artois_fr: Downloaded from Clearbit
# ✅ sephora_pl: Downloaded from Clearbit
# ✅ daikin-ksa_com: Downloaded from Clearbit
# ✅ sherwin-williams_com_ec: Downloaded from Clearbit
# ✅ culligantotalwater_com: Downloaded from Clearbit
# ⚠️ ecslupsk_pl: Clearbit 404, trying Google Favicon...
# ✅ ecslupsk_pl: Downloaded from Google Favicon
# ✅ kierpensions_co_uk: Downloaded from Clearbit
# ✅ bakertilly_ci: Downloaded from Clearbit
# ✅ allianz-rose_info: Downloaded from Clearbit
# ✅ linak_nl: Downloaded from Clearbit
# ✅ taylorfarmsdeli_com: Downloaded from Clearbit
# ✅ actemium_ch: Downloaded from Clearbit
# ✅ bakertilly_ky: Downloaded from Clearbit
# ✅ chip_pl: Downloaded from Clearbit
# ✅ grantthornton_com_sv: Downloaded from Clearbit
# ✅ bakertilly_com_pa: Downloaded from Clearbit
# ✅ vkf-renzel_com_tr: Downloaded from Clearbit
# ✅ fleishmanhillard_cn: Downloaded from Clearbit
# ✅ isover_hu: Downloaded from Clearbit
# ✅ bauder_at: Downloaded from Clearbit
# ⚠️ renaulttersa_com_mx: Clearbit 404, trying Google Favicon...
# ✅ renaulttersa_com_mx: Downloaded from Google Favicon
# ✅ zktecoma_com: Downloaded from Clearbit
# ✅ aamcotulsa-memorial_com: Downloaded from Clearbit
# ✅ azets_ie: Downloaded from Clearbit
# ✅ lidl_lt: Downloaded from Clearbit
# ✅ mooresingapore_com: Downloaded from Clearbit
# ✅ urmet_com_br: Downloaded from Clearbit
# ✅ ccusa_com_au: Downloaded from Clearbit
# ✅ toysrus_com_sg: Downloaded from Clearbit
# ✅ aamcopasadenatx_com: Downloaded from Clearbit
# ✅ manpowergroup_no: Downloaded from Clearbit
# ✅ mapfre_pr: Downloaded from Clearbit
# ✅ medef-bearnetsoule_com: Downloaded from Clearbit
# ✅ moore_swiss: Downloaded from Clearbit
# ✅ ccusa_hu: Downloaded from Clearbit
# ✅ modshair-nuernberg_de: Downloaded from Clearbit
# ✅ cdu-aldenhoven_de: Downloaded from Clearbit
# ⚠️ axabreakdown_co_uk: Clearbit 404, trying Google Favicon...
# ❌ axabreakdown_co_uk: No logo found on Google Favicon
# ✅ mazda-autohaus-roessel-birkenau_de: Logo already exists, skipping download.
# ✅ crif_pl: Downloaded from Clearbit
# ⚠️ mazda-autohaus-sturne-grimma_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-sturne-grimma_de: Downloaded from Google Favicon
# ✅ manpowergroup_no: Logo already exists, skipping download.
# ✅ panpuri_fr: Downloaded from Clearbit
# ✅ despec_eu: Downloaded from Clearbit
# ✅ savethechildren_mx: Downloaded from Clearbit
# ⚠️ chicco_pl: Clearbit 404, trying Google Favicon...
# ❌ chicco_pl: No logo found on Google Favicon
# ⚠️ mazda-autohaus-fenzl-hauzenberg_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-fenzl-hauzenberg_de: Downloaded from Google Favicon
# ✅ algordanza_com_au: Downloaded from Clearbit
# ⚠️ honda-pirola_com: Clearbit 404, trying Google Favicon...
# ✅ honda-pirola_com: Downloaded from Google Favicon
# ⚠️ rotaryclubofessex_com: Clearbit 404, trying Google Favicon...
# ✅ rotaryclubofessex_com: Downloaded from Google Favicon
# ✅ bakertilly_com_pa: Logo already exists, skipping download.
# ✅ carglass_rs: Downloaded from Clearbit
# ✅ nutricia_nl: Downloaded from Clearbit
# ✅ toofacedcosmetics_jp: Downloaded from Clearbit
# ✅ linexaus_com_au: Downloaded from Clearbit
# ⚠️ seasonsrehab_in: Clearbit 404, trying Google Favicon...
# ✅ seasonsrehab_in: Downloaded from Google Favicon
# ✅ berlitz-dublin_ie: Downloaded from Clearbit
# ✅ julis-nuernberg_de: Downloaded from Clearbit
# ✅ linak_com_br: Downloaded from Clearbit
# ✅ wurth_fi: Downloaded from Clearbit
# ✅ daikincareers_com: Downloaded from Clearbit
# ✅ pkf_co_in: Downloaded from Clearbit
# ✅ worldvision_bo: Downloaded from Clearbit
# ✅ affidea_pt: Downloaded from Clearbit
# ✅ daikintexastechnologypark_com: Downloaded from Clearbit
# ⚠️ daikin-china_com_cn: Clearbit 404, trying Google Favicon...
# ❌ daikin-china_com_cn: No logo found on Google Favicon
# ✅ rubiomonocoat_com_au: Downloaded from Clearbit
# ✅ mitsubishi-motors_com_om: Downloaded from Clearbit
# ✅ mazda-autohaus-tabbouch-speyer_de: Downloaded from Clearbit
# ✅ kumonla_com: Downloaded from Clearbit
# ✅ infiniti-bahrain_com: Downloaded from Clearbit
# ⚠️ ford_vn_ua: Clearbit 404, trying Google Favicon...
# ✅ ford_vn_ua: Downloaded from Google Favicon
# ✅ linde-gas_nl: Downloaded from Clearbit
# ✅ aamcofeastervillepa_com: Downloaded from Clearbit
# ✅ engie_de: Downloaded from Clearbit
# ✅ scte-prod_herokuapp_com: Downloaded from Clearbit
# ✅ spie_lu: Downloaded from Clearbit
# ✅ mazda-autohaus-haese-erkrath-hochdahl_de: Downloaded from Clearbit
# ⚠️ intersport-arc1950_com: Clearbit 404, trying Google Favicon...
# ❌ intersport-arc1950_com: No logo found on Google Favicon
# ✅ savethechildren_it: Downloaded from Clearbit
# ⚠️ misterwhat_nl: Clearbit 404, trying Google Favicon...
# ✅ misterwhat_nl: Downloaded from Google Favicon
# ✅ saint-gobain_ru: Downloaded from Clearbit
# ✅ linde-electronics_com: Logo already exists, skipping download.
# ✅ ikea_es: Downloaded from Clearbit
# ✅ daikin_com_vn: Downloaded from Clearbit
# ✅ nobleprog_co_th: Downloaded from Clearbit
# ✅ aamcowintervillenc_com: Downloaded from Clearbit
# ⚠️ spitexaadorf_ch: Clearbit 404, trying Google Favicon...
# ✅ spitexaadorf_ch: Downloaded from Google Favicon
# ✅ veolia_in: Downloaded from Clearbit
# ✅ wurth_ua: Downloaded from Clearbit
# ✅ metlife_co_kr: Downloaded from Clearbit
# ✅ einhell_hr: Downloaded from Clearbit
# ⚠️ toyotafocsani_ro: Clearbit 404, trying Google Favicon...
# ✅ toyotafocsani_ro: Downloaded from Google Favicon
# ✅ aamco-newbraunfels_com: Downloaded from Clearbit
# ⚠️ bestrucksofmn_net: Clearbit 404, trying Google Favicon...
# ❌ bestrucksofmn_net: No logo found on Google Favicon
# ✅ berlitzph_com: Downloaded from Clearbit
# ✅ fmc-mexico_com: Downloaded from Clearbit
# ✅ mitsubishielectric_cz: Downloaded from Clearbit
# ⚠️ renaultsancosme_com_mx: Clearbit 404, trying Google Favicon...
# ✅ renaultsancosme_com_mx: Downloaded from Google Favicon
# ⚠️ mazda-autohaus-kilger-regen_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-kilger-regen_de: Downloaded from Google Favicon
# ⚠️ toupret_ch: Clearbit 404, trying Google Favicon...
# ✅ toupret_ch: Downloaded from Google Favicon
# ✅ mazdalakeland_com: Downloaded from Clearbit
# ✅ ikea_com_tr: Downloaded from Clearbit
# ✅ mazda-rzeszow-czach_pl: Downloaded from Clearbit
# ✅ ymca-cnw_org: Downloaded from Clearbit
# ✅ veolia_pt: Downloaded from Clearbit
# ⚠️ srpb2b_com: Clearbit 404, trying Google Favicon...
# ✅ srpb2b_com: Downloaded from Google Favicon
# ⚠️ aamcosantaclaritaca_com: Clearbit 404, trying Google Favicon...
# ✅ aamcosantaclaritaca_com: Downloaded from Google Favicon
# ✅ edenred_es: Downloaded from Clearbit
# ⚠️ airbnb_rs: Clearbit 404, trying Google Favicon...
# ✅ airbnb_rs: Downloaded from Google Favicon
# ✅ renaulttlalnepantla_com_mx: Downloaded from Clearbit
# ✅ dulux_pl: Downloaded from Clearbit
# ⚠️ thebodyshop_si: Clearbit 404, trying Google Favicon...
# ✅ thebodyshop_si: Downloaded from Google Favicon
# ✅ immunospot_eu: Downloaded from Clearbit
# ⚠️ kia-moeller-eisenach_de: Clearbit 404, trying Google Favicon...
# ✅ kia-moeller-eisenach_de: Downloaded from Google Favicon
# ✅ greatplacetowork_com_cy: Downloaded from Clearbit
# ✅ orange_sn: Downloaded from Clearbit
# ✅ bakertilly_dk: Downloaded from Clearbit
# ✅ mazda-autohaus-banaszak-kleve_de: Downloaded from Clearbit
# ✅ bakertilly_ke: Downloaded from Clearbit
# ✅ araihelmet_com: Downloaded from Clearbit
# ✅ nestle_mk: Downloaded from Clearbit
# ✅ globalconnectgroup_com: Downloaded from Clearbit
# ✅ aamcofortworth_com: Downloaded from Clearbit
# ✅ aamcosuffolkva_com: Downloaded from Clearbit
# ⚠️ papasaveriospizzeria_com: Clearbit 404, trying Google Favicon...
# ✅ papasaveriospizzeria_com: Downloaded from Google Favicon
# ✅ orange_sn: Logo already exists, skipping download.
# ✅ linde-gas_ee: Downloaded from Clearbit
# ✅ mazda-autohaus-elstner-jena_de: Downloaded from Clearbit
# ✅ servier_com_ar: Downloaded from Clearbit
# ⚠️ sitechnorthwest_com: Clearbit 404, trying Google Favicon...
# ✅ sitechnorthwest_com: Downloaded from Google Favicon
# ✅ rotary-bulgaria_org: Downloaded from Clearbit
# ✅ moog_co_uk: Downloaded from Clearbit
# ✅ kia-mueller-genthin_de: Downloaded from Clearbit
# ✅ carglass_gr: Downloaded from Clearbit
# ✅ murrelektronik_sk: Downloaded from Clearbit
# ✅ cfmotoperu_com: Downloaded from Clearbit
# ✅ aamcometuchen_com: Downloaded from Clearbit
# ✅ mazda-autohaus-dorner-riedlingen_de: Downloaded from Clearbit
# ⚠️ aamcotulsa-brokenarrow_com: Clearbit 404, trying Google Favicon...
# ✅ aamcotulsa-brokenarrow_com: Downloaded from Google Favicon
# ✅ mercyships_se: Downloaded from Clearbit
# ⚠️ mazda-service-koch-ludwigsfelde_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-service-koch-ludwigsfelde_de: Downloaded from Google Favicon
# ✅ kia-plt_ru: Downloaded from Clearbit
# ✅ lamborghini-zh_ch: Downloaded from Clearbit
# ✅ secureparking_co_id: Downloaded from Clearbit
# ✅ solatube_se: Downloaded from Clearbit
# ⚠️ aviapolska_pl: Clearbit 404, trying Google Favicon...
# ❌ aviapolska_pl: No logo found on Google Favicon
# ✅ statkraft_ie: Downloaded from Clearbit
# ✅ carglass_cz: Downloaded from Clearbit
# ✅ intersport-martinique-guadeloupe_fr: Downloaded from Clearbit
# ✅ bakertilly_bg: Downloaded from Clearbit
# ✅ allianz-assistance_ie: Downloaded from Clearbit
# ✅ isic_de: Downloaded from Clearbit
# ✅ starbucks_co_nz: Downloaded from Clearbit
# ⚠️ benu_ee: Clearbit 404, trying Google Favicon...
# ✅ benu_ee: Downloaded from Google Favicon
# ✅ sto_hr: Downloaded from Clearbit
# ✅ decathlon_ch: Downloaded from Clearbit
# ✅ enterprise_dk: Downloaded from Clearbit
# ✅ demeter-bw_de: Downloaded from Clearbit
# ✅ carlsjr_com_sg: Downloaded from Clearbit
# ⚠️ dertour_sk: Clearbit 404, trying Google Favicon...
# ❌ dertour_sk: No logo found on Google Favicon
# ✅ linde-gas_at: Logo already exists, skipping download.
# ⚠️ mazda-autohaus-ludwig-halle-neustadt_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-ludwig-halle-neustadt_de: Downloaded from Google Favicon
# ✅ toyotaaktoy_com_tr: Downloaded from Clearbit
# ✅ savethechildren_it: Logo already exists, skipping download.
# ✅ mazda-angola-autozuid_com: Downloaded from Clearbit
# ✅ santillana_com_uy: Downloaded from Clearbit
# ✅ africell_ao: Downloaded from Clearbit
# ✅ crocs_ch: Downloaded from Clearbit
# ⚠️ mazda-ma_com: Clearbit 404, trying Google Favicon...
# ✅ mazda-ma_com: Downloaded from Google Favicon
# ✅ cdlbarreiras_com_br: Downloaded from Clearbit
# ✅ bonprix_nl: Downloaded from Clearbit
# ✅ mcdonalds_co_za: Downloaded from Clearbit
# ✅ pearsonclinical_co_uk: Downloaded from Clearbit
# ✅ tupperware_co_kr: Downloaded from Clearbit
# ✅ ford_if_ua: Downloaded from Clearbit
# ✅ ikea_ee: Downloaded from Clearbit
# ✅ mazda_fi: Downloaded from Clearbit
# ✅ toyotagocmenturk_com_tr: Downloaded from Clearbit
# ✅ mazda-autohaus-dorner-riedlingen_de: Logo already exists, skipping download.
# ⚠️ mazda-autohaus-buelo-naumburg_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-buelo-naumburg_de: Downloaded from Google Favicon
# ✅ veolia_pl: Downloaded from Clearbit
# ⚠️ culliganquadcities_com: Clearbit 404, trying Google Favicon...
# ✅ culliganquadcities_com: Downloaded from Google Favicon
# ✅ nikonschool_de: Downloaded from Clearbit
# ✅ baywa-re_vn: Downloaded from Clearbit
# ✅ carglass_gr: Logo already exists, skipping download.
# ✅ worldvision_org_nz: Downloaded from Clearbit
# ✅ bioderma-sk_com: Downloaded from Clearbit
# ⚠️ toyotabacau_ro: Clearbit 404, trying Google Favicon...
# ✅ toyotabacau_ro: Downloaded from Google Favicon
# ✅ toysrus_com_my: Downloaded from Clearbit
# ✅ medef-corse_com: Downloaded from Clearbit
# ✅ mcdonalds_md: Downloaded from Clearbit
# ✅ aamcoconwaysc_com: Downloaded from Clearbit
# ✅ murrelektronik_be: Downloaded from Clearbit
# ✅ decathlon_hu: Downloaded from Clearbit
# ✅ jungheinrich_com_sg: Downloaded from Clearbit
# ✅ culliganwatertreatment_com: Downloaded from Clearbit
# ⚠️ mazda-autohaus-thoss-falkenstein_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-thoss-falkenstein_de: Downloaded from Google Favicon
# ✅ bbraun_ae: Downloaded from Clearbit
# ✅ isover_se: Downloaded from Clearbit
# ✅ synlab_com_gh: Downloaded from Clearbit
# ✅ culligantulsa_com: Downloaded from Clearbit
# ✅ rutscherlebnis_at: Downloaded from Clearbit
# ✅ grantthornton_com_ve: Downloaded from Clearbit
# ✅ adecco_com_sg: Downloaded from Clearbit
# ✅ engie_cl: Logo already exists, skipping download.
# ✅ modshair-bielefeld_de: Downloaded from Clearbit
# ✅ aamcoeverett_com: Downloaded from Clearbit
# ✅ reedglobal_hu: Downloaded from Clearbit
# ✅ mazdaoforange_com: Downloaded from Clearbit
# ✅ reedglobal_pl: Downloaded from Clearbit
# ✅ actemium_pt: Downloaded from Clearbit
# ✅ pearsonclinical_ca: Downloaded from Clearbit
# ✅ kiamarin_com: Downloaded from Clearbit
# ⚠️ toyota-annecy_fr: Clearbit 404, trying Google Favicon...
# ✅ toyota-annecy_fr: Downloaded from Google Favicon
# ✅ medef-sarthe_fr: Downloaded from Clearbit
# ✅ aamcoclaymontde_com: Downloaded from Clearbit
# ✅ bosch-industry-consulting_com: Downloaded from Clearbit
# ✅ bbraun_ca: Downloaded from Clearbit
# ✅ bakertilly_lv: Downloaded from Clearbit
# ✅ flashbay_com_my: Downloaded from Clearbit
# ✅ murrelektronik_hu: Downloaded from Clearbit
# ✅ bakertilly_sg: Downloaded from Clearbit
# ✅ pingusenglish_co_id: Downloaded from Clearbit
# ✅ atalian_pl: Downloaded from Clearbit
# ✅ daikin_com_vn: Logo already exists, skipping download.
# ✅ ebay_cn: Logo already exists, skipping download.
# ⚠️ linde_co_th: Clearbit 404, trying Google Favicon...
# ✅ linde_co_th: Downloaded from Google Favicon
# ✅ aamcoeastmesa_com: Downloaded from Clearbit
# ⚠️ repsol_in_ua: Clearbit 404, trying Google Favicon...
# ✅ repsol_in_ua: Downloaded from Google Favicon
# ✅ engie-africa_com: Downloaded from Clearbit
# ✅ veka_pt: Downloaded from Clearbit
# ✅ stanbicbank_co_bw: Downloaded from Clearbit
# ✅ zalando_no: Downloaded from Clearbit
# ✅ spitexgossau_ch: Downloaded from Clearbit
# ✅ linde-gas_ee: Logo already exists, skipping download.
# ✅ toysrus_com_ph: Downloaded from Clearbit
# ⚠️ spitex-region-stockhorn_ch: Clearbit 404, trying Google Favicon...
# ✅ spitex-region-stockhorn_ch: Downloaded from Google Favicon
# ✅ algeco_sk: Downloaded from Clearbit
# ✅ aamcoparkvillemd_com: Downloaded from Clearbit
# ✅ mazdaofamarillo_com: Logo already exists, skipping download.
# ✅ wuerth_com_hr: Downloaded from Clearbit
# ⚠️ autosecuritas-ct-notre-dame-doe_fr: Clearbit 404, trying Google Favicon...
# ✅ autosecuritas-ct-notre-dame-doe_fr: Downloaded from Google Favicon
# ✅ mazda-autohaus-lotspeich-muenchen_de: Downloaded from Clearbit
# ✅ actemium_com: Downloaded from Clearbit
# ✅ veoliawatertechnologies_fi: Downloaded from Clearbit
# ✅ flashbay_co_nz: Downloaded from Clearbit
# ⚠️ ford_dn_ua: Clearbit 404, trying Google Favicon...
# ✅ ford_dn_ua: Downloaded from Google Favicon
# ✅ mazda_ru: Downloaded from Clearbit
# ⚠️ aamcowestbroward_com: Clearbit 404, trying Google Favicon...
# ✅ aamcowestbroward_com: Downloaded from Google Favicon
# ✅ yonyou_com_hk: Downloaded from Clearbit
# ⚠️ renaultcampeche_mx: Clearbit 404, trying Google Favicon...
# ✅ renaultcampeche_mx: Downloaded from Google Favicon
# ✅ viacon_no: Downloaded from Clearbit
# ✅ aamco-omahasouth_com: Downloaded from Clearbit
# ✅ veolia_bg: Downloaded from Clearbit
# ✅ adecco_co_th: Downloaded from Clearbit
# ⚠️ nordicpharma_pt: Clearbit 404, trying Google Favicon...
# ✅ nordicpharma_pt: Downloaded from Google Favicon
# ⚠️ aamcohialeahfl_com: Clearbit 404, trying Google Favicon...
# ✅ aamcohialeahfl_com: Downloaded from Google Favicon
# ✅ linde-gas_ee: Logo already exists, skipping download.
# ⚠️ kiaofdaphne_com: Clearbit 404, trying Google Favicon...
# ✅ kiaofdaphne_com: Downloaded from Google Favicon
# ✅ isover_ua: Downloaded from Clearbit
# ✅ toyotaaktoy_com_tr: Logo already exists, skipping download.
# ✅ vans_at: Downloaded from Clearbit
# ✅ globalconnectcarrier_com: Downloaded from Clearbit
# ✅ vbh_be: Downloaded from Clearbit
# ✅ mazda-autohaus-fritsche-grossschoenau_de: Downloaded from Clearbit
# ✅ techtel_com_sg: Downloaded from Clearbit
# ⚠️ spitex-oberthurgau_ch: Clearbit 404, trying Google Favicon...
# ✅ spitex-oberthurgau_ch: Downloaded from Google Favicon
# ✅ pragroup_pl: Downloaded from Clearbit
# ✅ veoliawatertechnologies_pl: Downloaded from Clearbit
# ✅ cvjm-hemer_de: Downloaded from Clearbit
# ✅ mazda-sosnowiec-mirai_pl: Downloaded from Clearbit
# ✅ yves-rocher_pt: Downloaded from Clearbit
# ✅ wwf_no: Downloaded from Clearbit
# ✅ vkf-renzel_ro: Downloaded from Clearbit
# ✅ rockvalleyculligan_com: Downloaded from Clearbit
# ✅ mazda-autohaus-sturne-grimma_de: Logo already exists, skipping download.
# ✅ atalian_hu: Downloaded from Clearbit
# ✅ amnesty_id: Downloaded from Clearbit
# ✅ veolia_fi: Downloaded from Clearbit
# ✅ roca_co_th: Downloaded from Clearbit
# ✅ fleishmanhillard_ph: Downloaded from Clearbit
# ✅ avia-belgomine_be: Downloaded from Clearbit
# ✅ greatplacetowork_se: Downloaded from Clearbit
# ✅ toyota-bauer_at: Downloaded from Clearbit
# ✅ toyota-rillieux_fr: Downloaded from Clearbit
# ⚠️ manpowergroup_dk: Clearbit 404, trying Google Favicon...
# ✅ manpowergroup_dk: Downloaded from Google Favicon
# ✅ dysartsservicecenter_com: Downloaded from Clearbit
# ✅ pefc_fi: Downloaded from Clearbit
# ✅ aamcoindependencemo_com: Downloaded from Clearbit
# ✅ caspak_co_nz: Downloaded from Clearbit
# ✅ toyotasandikci_com_tr: Downloaded from Clearbit
# ✅ spitexzug_ch: Downloaded from Clearbit
# ✅ bakertilly_sl: Downloaded from Clearbit
# ✅ papajohns_co_nl: Downloaded from Clearbit
# ⚠️ spitex-oberfreiamt_ch: Clearbit 404, trying Google Favicon...
# ✅ spitex-oberfreiamt_ch: Downloaded from Google Favicon
# ⚠️ mazda-autohaus-schindlbeck-straubing_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-schindlbeck-straubing_de: Downloaded from Google Favicon
# ⚠️ chicco_ru: Clearbit 404, trying Google Favicon...
# ❌ chicco_ru: No logo found on Google Favicon
# ✅ veolia_co_za: Downloaded from Clearbit
# ⚠️ misterwhat_pt: Clearbit 404, trying Google Favicon...
# ✅ misterwhat_pt: Downloaded from Google Favicon
# ⚠️ zalando_at: Clearbit 404, trying Google Favicon...
# ✅ zalando_at: Downloaded from Google Favicon
# ✅ shimadzu-la_com: Downloaded from Clearbit
# ✅ infiniti-abudhabi_com: Downloaded from Clearbit
# ✅ mazda-autohaus-mueller-und-thurnes-tholey_de: Downloaded from Clearbit
# ✅ aamcoburbank_com: Downloaded from Clearbit
# ✅ tupperware_es: Downloaded from Clearbit
# ⚠️ mazda-autohaus-albstadt-auto-domicil-ebingen_de: Clearbit 404, trying Google Favicon...
# ❌ mazda-autohaus-albstadt-auto-domicil-ebingen_de: No logo found on Google Favicon
# ✅ hondasemarangcenter_com: Downloaded from Clearbit
# ⚠️ adlatus-nordwestschweiz_ch: Clearbit 404, trying Google Favicon...
# ✅ adlatus-nordwestschweiz_ch: Downloaded from Google Favicon
# ✅ demetercs_eu: Downloaded from Clearbit
# ✅ sitechsolutions_com: Downloaded from Clearbit
# ✅ subaru-bd_com: Downloaded from Clearbit
# ⚠️ toysrus_fr: Clearbit 404, trying Google Favicon...
# ❌ toysrus_fr: No logo found on Google Favicon
# ✅ mazda-krakow-kazokuluzar_pl: Downloaded from Clearbit
# ✅ carglass_hu: Downloaded from Clearbit
# ⚠️ astrazeneca_hu: Clearbit 404, trying Google Favicon...
# ✅ astrazeneca_hu: Downloaded from Google Favicon
# ✅ pragroup_com_au: Downloaded from Clearbit
# ✅ aonsolutions_com_cy: Downloaded from Clearbit
# ⚠️ toyotaortakoy_com_tr: Clearbit 404, trying Google Favicon...
# ✅ toyotaortakoy_com_tr: Downloaded from Google Favicon
# ✅ culligansiouxcity_com: Downloaded from Clearbit
# ✅ kia-ci_com: Downloaded from Clearbit
# ✅ kia-crimea_ru: Downloaded from Clearbit
# ✅ einhell_com_ar: Downloaded from Clearbit
# ✅ lidl-ni_co_uk: Downloaded from Clearbit
# ✅ acuraofwestchester_com: Downloaded from Clearbit
# ⚠️ chicco_co_nz: Clearbit 404, trying Google Favicon...
# ❌ chicco_co_nz: No logo found on Google Favicon
# ✅ veolia_am: Downloaded from Clearbit
# ✅ wurthsaudi_com: Logo already exists, skipping download.
# ✅ lindesaude_pt: Downloaded from Clearbit
# ✅ bioderma_it: Downloaded from Clearbit
# ✅ rationalstock_es: Downloaded from Clearbit
# ✅ crocs_co_id: Logo already exists, skipping download.
# ✅ bbraun_ph: Downloaded from Clearbit
# ✅ wurth_com_uy: Logo already exists, skipping download.
# ⚠️ lidl-giftcard_eu: Clearbit 404, trying Google Favicon...
# ❌ lidl-giftcard_eu: No logo found on Google Favicon
# ✅ salvationarmy_org_sg: Downloaded from Clearbit
# ✅ hyundaiblacktown_com_au: Downloaded from Clearbit
# ✅ kuraray_us_com: Downloaded from Clearbit
# ✅ infiniti-dubai_com: Downloaded from Clearbit
# ✅ muvpropiedades_com_ar: Downloaded from Clearbit
# ✅ myron_ca: Downloaded from Clearbit
# ✅ crocssa_co_za: Downloaded from Clearbit
# ✅ mercyships_dk: Downloaded from Clearbit
# ✅ mazda-uae_com: Downloaded from Clearbit
# ✅ aamcomissouricitytx_com: Downloaded from Clearbit
# ✅ colorflexpackaging_com: Downloaded from Clearbit
# ✅ linexcoloradosprings_com: Downloaded from Clearbit
# ✅ propertyfinder_com: Downloaded from Clearbit
# ✅ misterwhat_pl: Downloaded from Clearbit
# ⚠️ mazda-autohaus-doerenkaemper-bad-hersfeld_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-doerenkaemper-bad-hersfeld_de: Downloaded from Google Favicon
# ✅ linde-gaz_pl: Downloaded from Clearbit
# ✅ servier_co_uk: Downloaded from Clearbit
# ✅ veolia_ca: Logo already exists, skipping download.
# ⚠️ pingusenglishbd_com: Clearbit 404, trying Google Favicon...
# ✅ pingusenglishbd_com: Downloaded from Google Favicon
# ✅ cvjm-muensingen_de: Downloaded from Clearbit
# ✅ aamcopompanobeach_com: Downloaded from Clearbit
# ⚠️ aamcovinelandnj_com: Clearbit 404, trying Google Favicon...
# ✅ aamcovinelandnj_com: Downloaded from Google Favicon
# ✅ nestle_bg: Downloaded from Clearbit
# ⚠️ linexofmacon_com: Clearbit 404, trying Google Favicon...
# ✅ linexofmacon_com: Downloaded from Google Favicon
# ✅ worldvision_org_sv: Downloaded from Clearbit
# ✅ inductothermgroup_com_br: Downloaded from Clearbit
# ✅ plameco_nl: Downloaded from Clearbit
# ✅ wurth_lk: Downloaded from Clearbit
# ✅ mazda-press_com: Downloaded from Clearbit
# ✅ bbraun_lt: Downloaded from Clearbit
# ✅ howden_co_il: Downloaded from Clearbit
# ✅ fattalhotelgroup_com: Downloaded from Clearbit
# ✅ mazda_hu: Downloaded from Clearbit
# ✅ allianz_com_gr: Downloaded from Clearbit
# ⚠️ tgmresearch_vn: Clearbit 404, trying Google Favicon...
# ✅ tgmresearch_vn: Downloaded from Google Favicon
# ✅ lightspeedhq_fr: Downloaded from Clearbit
# ✅ wwf_org: Downloaded from Clearbit
# ✅ mazda-rzeszow-czach_pl: Logo already exists, skipping download.
# ⚠️ mazda-autohaus-stiefel-muehlacker_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-stiefel-muehlacker_de: Downloaded from Google Favicon
# ⚠️ mazda-autohaus-boehme-lutherstadt-wittenberg_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-boehme-lutherstadt-wittenberg_de: Downloaded from Google Favicon
# ✅ linexofwilliston_com: Downloaded from Clearbit
# ✅ bakertillymapema_se: Downloaded from Clearbit
# ✅ rotary_hr: Downloaded from Clearbit
# ✅ honda-rouen_com: Downloaded from Clearbit
# ⚠️ spitexgaiserwald_ch: Clearbit 404, trying Google Favicon...
# ✅ spitexgaiserwald_ch: Downloaded from Google Favicon
# ✅ mazdacity_com: Downloaded from Clearbit
# ✅ fmlogistic_cz: Downloaded from Clearbit
# ✅ bbraun_co_uk: Downloaded from Clearbit
# ✅ kia-kmv_ru: Downloaded from Clearbit
# ⚠️ spitex-imboden_ch: Clearbit 404, trying Google Favicon...
# ✅ spitex-imboden_ch: Downloaded from Google Favicon
# ⚠️ brother-slovakia_sk: Clearbit 404, trying Google Favicon...
# ✅ brother-slovakia_sk: Downloaded from Google Favicon
# ✅ etxt_biz: Downloaded from Clearbit
# ✅ adecco_rs: Downloaded from Clearbit
# ✅ savethechildren_or_id: Downloaded from Clearbit
# ✅ julis-muenchen_de: Downloaded from Clearbit
# ✅ bakertillymapema_se: Logo already exists, skipping download.
# ✅ intersport_si: Downloaded from Clearbit
# ✅ spitex-waedenswil_ch: Downloaded from Clearbit
# ✅ santander_pt: Downloaded from Clearbit
# ✅ synergie_com: Downloaded from Clearbit
# ✅ santander_de: Downloaded from Clearbit
# ✅ trijit_uk: Downloaded from Clearbit
# ✅ mitsubishi-motors_it: Downloaded from Clearbit
# ✅ tevamexico_com_mx: Downloaded from Clearbit
# ✅ budget-egypt_com: Downloaded from Clearbit
# ✅ wuerthmarket_ru: Downloaded from Clearbit
# ✅ greatplacetowork_com_pe: Downloaded from Clearbit
# ✅ greatplacetowork_co_kr: Downloaded from Clearbit
# ✅ toshiba-water_com: Downloaded from Clearbit
# ✅ allianz-rose_info: Logo already exists, skipping download.
# ✅ axa_dz: Downloaded from Clearbit
# ✅ allianz-genc_de: Downloaded from Clearbit
# ✅ suttontools_co_nz: Downloaded from Clearbit
# ✅ applebees_com_gt: Downloaded from Clearbit
# ⚠️ mazda-autohaus-abs-erlangen_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-abs-erlangen_de: Downloaded from Google Favicon
# ⚠️ daikin_com_mm: Clearbit 404, trying Google Favicon...
# ✅ daikin_com_mm: Downloaded from Google Favicon
# ✅ aamcopottstownpa_com: Downloaded from Clearbit
# ⚠️ rotary-club-paris-se_org: Clearbit 404, trying Google Favicon...
# ✅ rotary-club-paris-se_org: Downloaded from Google Favicon
# ✅ eurofins_at: Downloaded from Clearbit
# ✅ bbraun_com_vn: Downloaded from Clearbit
# ✅ linde-finance_com: Logo already exists, skipping download.
# ✅ sto-ukraine_com: Downloaded from Clearbit
# ✅ mazda-autohaus-wilhelm-huellhorst_de: Downloaded from Clearbit
# ✅ amway_at: Downloaded from Clearbit
# ✅ steinbacher_pl: Downloaded from Clearbit
# ✅ shopee_in: Downloaded from Clearbit
# ✅ aamcosilverspringmd_com: Downloaded from Clearbit
# ⚠️ mazda-autohaus-lehmann-senftenberg_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-lehmann-senftenberg_de: Downloaded from Google Favicon
# ✅ axa_ad: Downloaded from Clearbit
# ⚠️ mazdaofspartanburg_com: Clearbit 404, trying Google Favicon...
# ✅ mazdaofspartanburg_com: Downloaded from Google Favicon
# ⚠️ brother-industrial_md: Clearbit 404, trying Google Favicon...
# ❌ brother-industrial_md: No logo found on Google Favicon
# ✅ compassion_es: Downloaded from Clearbit
# ⚠️ chicco_ru: Clearbit 404, trying Google Favicon...
# ❌ chicco_ru: No logo found on Google Favicon
# ✅ aamco-bellevue_com: Downloaded from Clearbit
# ✅ nordicpharma_nl: Downloaded from Clearbit
# ✅ hyundaichullora_com_au: Downloaded from Clearbit
# ✅ amnesty_id: Logo already exists, skipping download.
# ✅ zalando_be: Downloaded from Clearbit
# ✅ mazdafwb_com: Downloaded from Clearbit
# ✅ demeter_at: Downloaded from Clearbit
# ✅ honda_cl: Downloaded from Clearbit
# ✅ toyotakar_com_tr: Downloaded from Clearbit
# ⚠️ saint-gobain-glass_es: Clearbit 404, trying Google Favicon...
# ✅ saint-gobain-glass_es: Downloaded from Google Favicon
# ✅ reedglobal_bg: Downloaded from Clearbit
# ✅ axa-assistance_ma: Downloaded from Clearbit
# ✅ intersport_com_cy: Downloaded from Clearbit
# ✅ intersport-courchevel1850_com: Downloaded from Clearbit
# ✅ decathlon_com_tr: Downloaded from Clearbit
# ✅ mazda-autohaus-heider-dresden_de: Downloaded from Clearbit
# ✅ avis_co_mw: Downloaded from Clearbit
# ⚠️ freseniuskidneycare_ph: Clearbit 404, trying Google Favicon...
# ✅ freseniuskidneycare_ph: Downloaded from Google Favicon
# ✅ bakertilly_gt: Downloaded from Clearbit
# ✅ aamcochannelviewtx_com: Downloaded from Clearbit
# ✅ drekopf-kanalservice_de: Downloaded from Clearbit
# ✅ mcdonalds_ma: Downloaded from Clearbit
# ✅ airbnb_cz: Downloaded from Clearbit
# ⚠️ howdensafetysolutions_com: Clearbit 404, trying Google Favicon...
# ✅ howdensafetysolutions_com: Downloaded from Google Favicon
# ✅ sto-sea_com: Downloaded from Clearbit
# ✅ toyotadolak_cz: Downloaded from Clearbit
# ✅ orange-bissau_com: Downloaded from Clearbit
# ✅ elizabetharden_tw: Downloaded from Clearbit
# ⚠️ bioderma_com_hr: Clearbit 404, trying Google Favicon...
# ✅ bioderma_com_hr: Downloaded from Google Favicon
# ✅ mazda-autohaus-rausch-dresden_de: Downloaded from Clearbit
# ✅ bbraun_se: Downloaded from Clearbit
# ✅ besins-healthcare_nl: Downloaded from Clearbit
# ⚠️ abilways_be: Clearbit 404, trying Google Favicon...
# ❌ abilways_be: No logo found on Google Favicon
# ✅ kia-chita_ru: Downloaded from Clearbit
# ✅ spitex-hoefe_ch: Downloaded from Clearbit
# ✅ fmlogistic_ro: Downloaded from Clearbit
# ✅ ikea_pr: Downloaded from Clearbit
# ✅ medef-ain_fr: Downloaded from Clearbit
# ✅ decathlon-karriere_de: Downloaded from Clearbit
# ✅ veoliawatertechnologies_fr: Downloaded from Clearbit
# ⚠️ linde-gas_sk: Clearbit 404, trying Google Favicon...
# ✅ linde-gas_sk: Downloaded from Google Favicon
# ✅ murrelektronik_kr: Downloaded from Clearbit
# ✅ synlab_cz: Downloaded from Clearbit
# ✅ islprgac_org: Downloaded from Clearbit
# ✅ sto_fi: Downloaded from Clearbit
# ✅ airbnb_com_pe: Downloaded from Clearbit
# ⚠️ mazda-autohaus-voigtlaender-meyer-hamburg_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-voigtlaender-meyer-hamburg_de: Downloaded from Google Favicon
# ✅ carlsjr_fr: Downloaded from Clearbit
# ✅ bosch-industrial_com: Downloaded from Clearbit
# ✅ medef-somme_fr: Downloaded from Clearbit
# ⚠️ kawasaki-seufert_de: Clearbit 404, trying Google Favicon...
# ✅ kawasaki-seufert_de: Downloaded from Google Favicon
# ✅ fordmediacenter_nl: Downloaded from Clearbit
# ✅ pingusenglish_com_cy: Downloaded from Clearbit
# ✅ ymcawaycross_com: Downloaded from Clearbit
# ✅ murrelektronik_no: Downloaded from Clearbit
# ✅ flashbay_co_nz: Logo already exists, skipping download.
# ✅ affidea_lt: Downloaded from Clearbit
# ⚠️ kia-hotz-gardelegen_de: Clearbit 404, trying Google Favicon...
# ✅ kia-hotz-gardelegen_de: Downloaded from Google Favicon
# ✅ flashbay_fr: Downloaded from Clearbit
# ✅ saint-gobain-solutions_nl: Downloaded from Clearbit
# ✅ fmlogistic_com_ua: Downloaded from Clearbit
# ⚠️ aamcoroslindalema_com: Clearbit 404, trying Google Favicon...
# ✅ aamcoroslindalema_com: Downloaded from Google Favicon
# ✅ nobleprog_ro: Downloaded from Clearbit
# ✅ intersport-grandbornand_com: Downloaded from Clearbit
# ✅ linexaus_com_au: Logo already exists, skipping download.
# ✅ soneparfrance_fr: Downloaded from Clearbit
# ✅ servier_pt: Downloaded from Clearbit
# ✅ pearsonclinical_com_au: Downloaded from Clearbit
# ✅ demeter-im-westen_de: Downloaded from Clearbit
# ✅ nutricia_ie: Downloaded from Clearbit
# ✅ renault_no: Downloaded from Clearbit
# ✅ intersport_be: Downloaded from Clearbit
# ⚠️ sans-sans_com_my: Clearbit 404, trying Google Favicon...
# ✅ sans-sans_com_my: Downloaded from Google Favicon
# ✅ mtn_com_gh: Downloaded from Clearbit
# ✅ vivaconagua_org_za: Downloaded from Clearbit
# ✅ aamcobrooklyn-ralphave_com: Downloaded from Clearbit
# ✅ decathlon_hu: Logo already exists, skipping download.
# ⚠️ miniso_nc: Clearbit 404, trying Google Favicon...
# ✅ miniso_nc: Downloaded from Google Favicon
# ✅ savethechildren_org_za: Downloaded from Clearbit
# ✅ kia-christ-ansbach_de: Downloaded from Clearbit
# ✅ worldvision_cl: Downloaded from Clearbit
# ✅ veoliawatertechnologies_fi: Logo already exists, skipping download.
# ⚠️ mazda_lt: Clearbit 404, trying Google Favicon...
# ✅ mazda_lt: Downloaded from Google Favicon
# ✅ ardex_at: Downloaded from Clearbit
# ✅ kia-strehle-dresden_de: Downloaded from Clearbit
# ✅ vans_com_ar: Downloaded from Clearbit
# ✅ airbnb_com_ar: Downloaded from Clearbit
# ✅ pingusenglish_my: Downloaded from Clearbit
# ✅ daikinlebanon_com: Downloaded from Clearbit
# ✅ mazda-autohaus-lackmann-sendenhorst_de: Logo already exists, skipping download.
# ✅ mazdaofpottstown_com: Downloaded from Clearbit
# ✅ isover_com_br: Downloaded from Clearbit
# ✅ toyotabakircilarfethiye_com_tr: Downloaded from Clearbit
# ⚠️ mazda-automobile-weberpals-sonneberg-hoenbach_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-automobile-weberpals-sonneberg-hoenbach_de: Downloaded from Google Favicon
# ✅ menicon_com_au: Downloaded from Clearbit
# ✅ toyotacavdarli_com_tr: Downloaded from Clearbit
# ✅ fmlogistic_es: Downloaded from Clearbit
# ✅ veolia_ma: Downloaded from Clearbit
# ✅ aamcopinevillenc_com: Downloaded from Clearbit
# ✅ alcirclebiz_com: Downloaded from Clearbit
# ✅ renault_pe: Downloaded from Clearbit
# ✅ avis_com_ph: Downloaded from Clearbit
# ✅ atalian_com_tr: Downloaded from Clearbit
# ⚠️ ford_te_ua: Clearbit 404, trying Google Favicon...
# ✅ ford_te_ua: Downloaded from Google Favicon
# ✅ daikinafrica_com: Downloaded from Clearbit
# ✅ wurth_com_vn: Downloaded from Clearbit
# ✅ demeter_ch: Downloaded from Clearbit
# ✅ duracleanservicebybob_com: Downloaded from Clearbit
# ✅ minisoindia_com: Downloaded from Clearbit
# ✅ daikinegypt_com: Downloaded from Clearbit
# ✅ veolia_co_za: Logo already exists, skipping download.
# ✅ mazda-warszawa-bemomotors_pl: Downloaded from Clearbit
# ✅ billygraham_ca: Downloaded from Clearbit
# ✅ kiaonline_dk: Downloaded from Clearbit
# ✅ worldvision_org_sv: Logo already exists, skipping download.
# ✅ allianz_com_ar: Downloaded from Clearbit
# ✅ aamco-omahawest_com: Downloaded from Clearbit
# ✅ toyotasarar_com_tr: Downloaded from Clearbit
# ✅ manpowergroup_com_sg: Downloaded from Clearbit
# ✅ kiaofabilene_com: Downloaded from Clearbit
# ✅ nestle_com_tw: Downloaded from Clearbit
# ✅ actemium_at: Downloaded from Clearbit
# ✅ pearsonclinical_es: Downloaded from Clearbit
# ✅ veoliawatertechnologies_es: Downloaded from Clearbit
# ✅ synergiejobs_nl: Downloaded from Clearbit
# ✅ kumonshuppan_com: Downloaded from Clearbit
# ✅ trulynolenalagoas_com_br: Downloaded from Clearbit
# ⚠️ honda-rennes_com: Clearbit 404, trying Google Favicon...
# ✅ honda-rennes_com: Downloaded from Google Favicon
# ✅ fleishmanhillard_co_th: Downloaded from Clearbit
# ✅ linde-gas_lv: Downloaded from Clearbit
# ✅ nikonclub_fr: Downloaded from Clearbit
# ✅ fmlogistic_sk: Downloaded from Clearbit
# ✅ toyotaakkoyunlu_com_tr: Downloaded from Clearbit
# ✅ nordicpharma_co_uk: Downloaded from Clearbit
# ✅ vkf-renzel_cz: Downloaded from Clearbit
# ✅ aamcoinglewoodca_com: Downloaded from Clearbit
# ✅ bakertilly_lk: Downloaded from Clearbit
# ✅ toyotaotojen_com_tr: Downloaded from Clearbit
# ✅ stanbicbank_co_zm: Downloaded from Clearbit
# ⚠️ mazda-autohaus-hansmann-melsungen_de: Clearbit 404, trying Google Favicon...
# ✅ mazda-autohaus-hansmann-melsungen_de: Downloaded from Google Favicon
# ✅ bakertilly_fr: Downloaded from Clearbit
# ⚠️ europa-union-diepholz_de: Clearbit 404, trying Google Favicon...
# ✅ europa-union-diepholz_de: Downloaded from Google Favicon
# ✅ synlab_hr: Downloaded from Clearbit
# ✅ nestle_pl: Downloaded from Clearbit
# ✅ toyotaconstanta_ro: Downloaded from Clearbit
# ✅ toyotagoktepe_com_tr: Downloaded from Clearbit
# ✅ veolia_com_sg: Downloaded from Clearbit
# ✅ benu_nl: Downloaded from Clearbit
# ✅ job-impulse_hu: Downloaded from Clearbit
# ✅ renaultchiapas_com_mx: Downloaded from Clearbit
# ✅ pkffinconta_ro: Downloaded from Clearbit
# ⚠️ aamcoalexandriava_com: Clearbit 404, trying Google Favicon...
# ✅ aamcoalexandriava_com: Downloaded from Google Favicon
# ✅ bakertillylb_com: Downloaded from Clearbit
# ✅ mcvitiesindia_com: Downloaded from Clearbit
# ✅ savethechildren_org_au: Downloaded from Clearbit
# ✅ ardex_dk: Downloaded from Clearbit
# ⚠️ isover_sk: Clearbit 404, trying Google Favicon...
# ✅ isover_sk: Downloaded from Google Favicon
# ✅ plastoplan_pl: Downloaded from Clearbit
# ✅ cdvi_ch: Downloaded from Clearbit
# ✅ aamcovirginiabeachva_com: Downloaded from Clearbit
# ✅ veoliawatertechnologies_it: Downloaded from Clearbit
# ✅ actemium_ch: Logo already exists, skipping download.
# ✅ mapfre_com_ni: Downloaded from Clearbit
# ✅ mazda_ua: Downloaded from Clearbit
# ✅ aliaxis_cz: Downloaded from Clearbit
# ✅ airbnb_com_hk: Downloaded from Clearbit
# ✅ ford_vn_ua: Logo already exists, skipping download.
# ✅ kiaofduluth_com: Downloaded from Clearbit
# ✅ mazda_com_ec: Downloaded from Clearbit
# ✅ greatplacetowork_lu: Downloaded from Clearbit
# ✅ plameco_be: Downloaded from Clearbit
# ✅ hahn-kolb_mx: Downloaded from Clearbit
# ✅ airbnb_com_tw: Downloaded from Clearbit
# ✅ snapologyfranchising_com: Downloaded from Clearbit
# ⚠️ buydaikin_ro: Clearbit 404, trying Google Favicon...
# ✅ buydaikin_ro: Downloaded from Google Favicon
# ✅ modshair_co_nz: Downloaded from Clearbit
# ✅ affidea_es: Downloaded from Clearbit
# ✅ daikin_ge: Logo already exists, skipping download.
# ✅ kia-asc_ru: Downloaded from Clearbit
# ✅ modshair-mannheim_de: Downloaded from Clearbit
# ✅ pirtek_ie: Downloaded from Clearbit
# ⚠️ culligandelavan_com: Clearbit 404, trying Google Favicon...
# ✅ culligandelavan_com: Downloaded from Google Favicon
# ✅ isover_bg: Downloaded from Clearbit
# ✅ pingusenglish_ac_th: Downloaded from Clearbit
# ✅ kia-bachmann-wehretal_de: Downloaded from Clearbit
# ⚠️ schaumann_it: Clearbit 404, trying Google Favicon...
# ✅ schaumann_it: Downloaded from Google Favicon
# ✅ kia-brass-frankfurt_de: Downloaded from Clearbit
# ✅ ardex_com_tw: Downloaded from Clearbit
# ✅ brother_com_br: Downloaded from Clearbit
# ✅ svnchicagopm_com: Downloaded from Clearbit
# ✅ bakertilly-ca_com: Downloaded from Clearbit
# ✅ wwfchina_org: Downloaded from Clearbit
# ✅ linde-gaz_pl: Logo already exists, skipping download.
# ✅ medef-essonne_org: Downloaded from Clearbit
# ✅ lindesaude_pt: Logo already exists, skipping download.
# ✅ wordans_de: Downloaded from Clearbit
# ✅ mazda-autohaus-schmidt-meschede_de: Downloaded from Clearbit
# ✅ carglass_si: Downloaded from Clearbit
# ✅ storisell_com: Downloaded from Clearbit
# ✅ bakertilly_lk: Logo already exists, skipping download.
# ✅ linak-latinamerica_com: Downloaded from Clearbit
# ✅ engenmauritius_com: Downloaded from Clearbit
# ✅ decathlon_ro: Downloaded from Clearbit
# ✅ aamcoglendaleoldtown_com: Downloaded from Clearbit
# ✅ subaru_com_np: Downloaded from Clearbit
# ✅ decathlon_pl: Downloaded from Clearbit
# ✅ dulux_co_zw: Downloaded from Clearbit
# ✅ kilewswest_com: Downloaded from Clearbit
# ✅ mazda-autohaus-weber-magdeburg_de: Downloaded from Clearbit
# ✅ hyundai_ge: Downloaded from Clearbit
# ✅ mazda-tarnowskiegory-mirai_pl: Downloaded from Clearbit
# ✅ servier_hu: Downloaded from Clearbit
# ✅ childrenandteendentalfl_com: Downloaded from Clearbit
# ✅ vans_es: Downloaded from Clearbit
# ✅ linde-electronics_com: Logo already exists, skipping download.
# ✅ subaru_com_pa: Downloaded from Clearbit
# ✅ humanasecondhand_se: Downloaded from Clearbit
# ✅ toyotabucurestinord_ro: Downloaded from Clearbit
# ✅ manpowergroup_com_sg: Logo already exists, skipping download.
# ✅ advocarenewbornnetwork_com: Downloaded from Clearbit
# ⚠️ lindeoilandgas_com: Clearbit 404, trying Google Favicon...
# ✅ lindeoilandgas_com: Downloaded from Google Favicon
# ✅ intersport_fi: Downloaded from Clearbit
# ✅ ikea_co_id: Downloaded from Clearbit
# ✅ remax-go_com_ar: Downloaded from Clearbit
# ✅ lvs-oxford_org_uk: Downloaded from Clearbit
# ✅ castsoftware_it: Downloaded from Clearbit
# ✅ wurth_hu: Downloaded from Clearbit
# ✅ veoliawatertechnologies_de: Downloaded from Clearbit
# ✅ jll_co_kr: Downloaded from Clearbit
# ✅ adeccome_com: Downloaded from Clearbit
# ✅ aamcomorristown_com: Downloaded from Clearbit
# ✅ promat_ch: Downloaded from Clearbit
# ✅ msd-animal-health_pt: Downloaded from Clearbit
# ✅ kia-gj-remagen-rolandseck_de: Downloaded from Clearbit
# ✅ netterden_com: Downloaded from Clearbit
# ✅ sto-ukraine_com: Logo already exists, skipping download.
# ✅ bbraun_co: Downloaded from Clearbit
# ✅ hertz_com_ge: Downloaded from Clearbit
# ✅ worldvision_al: Downloaded from Clearbit
# ✅ fmlogistic_sk: Logo already exists, skipping download.
# ⚠️ zalando_ee: Clearbit 404, trying Google Favicon...
# ✅ zalando_ee: Downloaded from Google Favicon
# ✅ landi_swiss: Downloaded from Clearbit
# ✅ crif_cz: Downloaded from Clearbit
# ✅ hansa-flex_com_cn: Downloaded from Clearbit
# ✅ titancontainers_co_nz: Downloaded from Clearbit
# ✅ linde_pe: Logo already exists, skipping download.
# ✅ trisa_bg: Downloaded from Clearbit
# ✅ carglass_hr: Downloaded from Clearbit
# ✅ toyotamezcar_com_tr: Downloaded from Clearbit
# ✅ wurthindustry_ca: Downloaded from Clearbit
# ✅ entergy-neworleans_com: Downloaded from Clearbit
# ✅ aamcoelpaso-east_com: Downloaded from Clearbit
# ✅ nikon_com_sg: Downloaded from Clearbit
# ✅ experian_in: Downloaded from Clearbit
# ✅ kia-diamant-wiesbaden_de: Downloaded from Clearbit
# ✅ regalsprings_com_mx: Downloaded from Clearbit
# ✅ mazda112_com: Downloaded from Clearbit
# ...
# ✅ aamcowalnutcreekca_com: Downloaded from Clearbit
# ✅ bioderma_sg: Logo already exists, skipping download.
# ✅ nobleprog_com_ng: Downloaded from Clearbit
# ✅ nestle_lt: Downloaded from Clearbit
# ✅ msd-animal-health_be: Downloaded from Clearbit
# ✅ toyotasonkar_com_tr: Logo already exists, skipping download.
# ✅ wurth-international_com: Logo already exists, skipping download.
# ✅ bakertilly_lk: Logo already exists, skipping download.
# ✅ veka_fr: Downloaded from Clearbit
# ✅ aamcocedarparktx_com: Downloaded from Clearbit
# ✅ mazdabali_co_id: Logo already exists, skipping download.
# ✅ mazda-autohaus-flindt-marschacht_de: Logo already exists, skipping download.
# ✅ wwf_or_th: Logo already exists, skipping download.
# ✅ vkf-renzel_dk: Logo already exists, skipping download.
# ✅ delreg_com: Downloaded from Clearbit
# ✅ bakertilly_gi: Logo already exists, skipping download.
# ✅ actemium_at: Logo already exists, skipping download.
# ⚠️ poliform-spb_ru: Clearbit 404, trying Google Favicon...
# ✅ poliform-spb_ru: Downloaded from Google Favicon
# ✅ bbraun_co_th: Downloaded from Clearbit
# ✅ janegal_sk: Downloaded from Clearbit
# ✅ esseskincare_hk: Downloaded from Clearbit
# ✅ servier_gr: Logo already exists, skipping download.
# ✅ jetfriorefrigeracao_com_br: Downloaded from Clearbit
# ⚠️ nexicentraleurope_com: Clearbit 404, trying Google Favicon...
# ✅ nexicentraleurope_com: Downloaded from Google Favicon
# ✅ toyotaortakoy_com_tr: Logo already exists, skipping download.
# ✅ bakertilly_mu: Logo already exists, skipping download.
# ✅ kia_co_sz: Downloaded from Clearbit
# ✅ designmehair_cz: Downloaded from Clearbit
# ✅ digi-intl_co_jp: Downloaded from Clearbit
# ✅ pkfcs_co_nz: Downloaded from Clearbit
# ✅ norauto-empleo_es: Downloaded from Clearbit
# ✅ plameco-baer_de: Logo already exists, skipping download.
# ✅ ymcatoledo_org: Downloaded from Clearbit
# ⚠️ aamcolexingtonwest_com: Clearbit 404, trying Google Favicon...
# ✅ aamcolexingtonwest_com: Downloaded from Google Favicon
# ✅ sprachschule-aktiv-passau_de: Downloaded from Clearbit
# ✅ aeccglobal_lk: Downloaded from Clearbit
# ✅ nestle_com_bd: Downloaded from Clearbit
# ✅ pilotpen_ro: Downloaded from Clearbit
# ✅ actemium_se: Downloaded from Clearbit
# ✅ subaru_com_gt: Downloaded from Clearbit
# ✅ greatplacetowork_es: Downloaded from Clearbit
# ✅ bosch-climate_com_tr: Downloaded from Clearbit
# ✅ vkf-renzel_hu: Downloaded from Clearbit
# ✅ aamcogolflinks_com: Downloaded from Clearbit
# ✅ papajohns_com_tr: Downloaded from Clearbit
# ⚠️ carglass_ma: Clearbit 404, trying Google Favicon...
# ✅ carglass_ma: Downloaded from Google Favicon
# ⚠️ spitex-gaeu_ch: Clearbit 404, trying Google Favicon...
# ✅ spitex-gaeu_ch: Downloaded from Google Favicon
# ✅ reedglobal_hu: Logo already exists, skipping download.
# ✅ repsolsolgas_com: Downloaded from Clearbit
# ✅ spie-energotest_pl: Downloaded from Clearbit
# ✅ shercomotorcycles_it: Downloaded from Clearbit
# ✅ budget-ireland_co_uk: Downloaded from Clearbit
# ✅ bioderma_com: Downloaded from Clearbit
# ✅ ikea_com_hk: Logo already exists, skipping download.
# ✅ sompo-intl_com: Downloaded from Clearbit
# ✅ isuzuniaga_com: Downloaded from Clearbit
# ✅ sunnybrookprintshop_ca: Downloaded from Clearbit
# ✅ daikinlebanon_com: Logo already exists, skipping download.
# ✅ desjoyaux_co_uk: Downloaded from Clearbit
# ✅ crocs_com_ec: Logo already exists, skipping download.
# ✅ secom_vn: Downloaded from Clearbit
# ✅ aeccglobal_my: Downloaded from Clearbit
# ✅ linde_co_th: Logo already exists, skipping download.
# ✅ stora-drain_be: Downloaded from Clearbit
# ✅ toolstationjobs_nl: Downloaded from Clearbit
# ⚠️ rcchurch_com: Clearbit 404, trying Google Favicon...
# ✅ rcchurch_com: Downloaded from Google Favicon
# ✅ wwfchina_org: Logo already exists, skipping download.
# ✅ aamcooklahomacity-northwest_com: Downloaded from Clearbit
# ⚠️ dahmira_kz: Clearbit 404, trying Google Favicon...
# ✅ dahmira_kz: Downloaded from Google Favicon
# ✅ ikea_is: Logo already exists, skipping download.
# ✅ eurofins_hr: Downloaded from Clearbit
# ✅ crocs_com_ec: Logo already exists, skipping download.
# ✅ mazda-autohaus-huck-buehl_de: Downloaded from Clearbit
# ✅ mariagefreres_co_jp: Downloaded from Clearbit
# ✅ mazda-autohaus-ubben-aurich_de: Logo already exists, skipping download.
# ✅ isover_sk: Logo already exists, skipping download.
# ✅ statkraft_com_pe: Downloaded from Clearbit
# ✅ actemium_it: Logo already exists, skipping download.
# ✅ aonassurances_com: Downloaded from Clearbit
# ✅ mazda-autohaus-abs-erlangen_de: Logo already exists, skipping download.
# ✅ bioderma_com: Logo already exists, skipping download.
# ⚠️ hertz_yt: Clearbit 404, trying Google Favicon...
# ✅ hertz_yt: Downloaded from Google Favicon
# ✅ brother_com_mx: Downloaded from Clearbit
# ✅ zalando_no: Logo already exists, skipping download.
# ✅ medicover_de: Downloaded from Clearbit
# ⚠️ honda-dijon_com: Clearbit 404, trying Google Favicon...
# ✅ honda-dijon_com: Downloaded from Google Favicon
# ✅ allianz_ma: Downloaded from Clearbit
# ⚠️ lyspoland_pl: Clearbit 404, trying Google Favicon...
# ❌ lyspoland_pl: No logo found on Google Favicon
# ⚠️ ford_cl: Clearbit 404, trying Google Favicon...
# ✅ ford_cl: Downloaded from Google Favicon
# ✅ cvjm-muenchberg_de: Downloaded from Clearbit
# ✅ le-tech_co_uk: Downloaded from Clearbit
# ✅ daikin-ksa_com: Logo already exists, skipping download.
# ⚠️ fft-ps_pl: Clearbit 404, trying Google Favicon...
# ✅ fft-ps_pl: Downloaded from Google Favicon
# ⚠️ nissanmiddletownny_com: Clearbit 404, trying Google Favicon...
# ✅ nissanmiddletownny_com: Downloaded from Google Favicon
# ✅ wurth_hu: Logo already exists, skipping download.
# ✅ budget_com_do: Logo already exists, skipping download.
# ✅ techmatrix-asia_com: Downloaded from Clearbit
# ✅ adra_org_rs: Logo already exists, skipping download.
# ✅ mazdaofchicagoland_com: Logo already exists, skipping download.
# ✅ airbnb_ca: Downloaded from Clearbit
# ✅ aamcoglendaleca_com: Downloaded from Clearbit
# ⚠️ honda-mulhouse_com: Clearbit 404, trying Google Favicon...
# ✅ honda-mulhouse_com: Downloaded from Google Favicon
# ✅ daikin-iraq_com: Logo already exists, skipping download.
# ✅ airbnb_co_id: Downloaded from Clearbit
# ✅ affidea_pt: Logo already exists, skipping download.
# ✅ cedstone_ca: Downloaded from Clearbit
# ✅ mitsubishielectric-printing_com: Logo already exists, skipping download.
# ✅ duracleanservices_net: Downloaded from Clearbit
# ✅ papajohns_com_pk: Downloaded from Clearbit
# ✅ flashbay_es: Logo already exists, skipping download.
# ✅ tapflo_se: Downloaded from Clearbit
# ✅ shopee_com_mx: Downloaded from Clearbit
# ⚠️ shimadzu_co_kr: Clearbit 404, trying Google Favicon...
# ❌ shimadzu_co_kr: No logo found on Google Favicon
# ⚠️ aamcofortlauderdale-dixiehwy_com: Clearbit 404, trying Google Favicon...
# ✅ aamcofortlauderdale-dixiehwy_com: Downloaded from Google Favicon
# ✅ toyotaonatca_com_tr: Logo already exists, skipping download.
# ✅ nordicpharma_be: Downloaded from Clearbit
# ✅ nutrienagsolutions_ca: Downloaded from Clearbit
# ✅ bakertillyeg_com: Logo already exists, skipping download.
# ✅ toyotaaydogan_com_tr: Logo already exists, skipping download.
# ✅ aamcoblog_com: Downloaded from Clearbit
# ✅ decathlon_cz: Logo already exists, skipping download.
# ✅ toyotaborovali_com_tr: Logo already exists, skipping download.
# ✅ lueck-gruppe_de: Downloaded from Clearbit
# ✅ mazda-tarnowskiegory-mirai_pl: Logo already exists, skipping download.
# ✅ mazda-service-metz-marne_de: Logo already exists, skipping download.
# ✅ affidea_ch: Downloaded from Clearbit
# ✅ wurth_com_uy: Logo already exists, skipping download.
# ✅ aamcosouthsarasota_com: Downloaded from Clearbit
# ✅ servier_com_pa: Downloaded from Clearbit
# ✅ toyota-lyonsud_fr: Downloaded from Clearbit
# ⚠️ allianz-reiseschutz_de: Clearbit 404, trying Google Favicon...
# ❌ allianz-reiseschutz_de: No logo found on Google Favicon
# ✅ ebayglobalshipping_com: Logo already exists, skipping download.
# ✅ synergiejobs_at: Logo already exists, skipping download.
# ✅ dfcapital-investors_com: Downloaded from Clearbit
# ✅ salvationarmyflorida_org: Downloaded from Clearbit
# ✅ aamcobradenton_com: Downloaded from Clearbit
# ✅ sonepar_cz: Downloaded from Clearbit
# ✅ culliganlansing_com: Downloaded from Clearbit
# ✅ linde-healthcare_nl: Logo already exists, skipping download.
# ✅ kern-liebers_it: Downloaded from Clearbit
# ✅ statkraft_com_tr: Downloaded from Clearbit
# ✅ mazdaofconshohocken_com: Logo already exists, skipping download.
# ⚠️ tributek_com: Clearbit 404, trying Google Favicon...
# ✅ tributek_com: Downloaded from Google Favicon
# ✅ mtn_cg: Downloaded from Clearbit
# ✅ shimadzumea_com: Downloaded from Clearbit
# ✅ greatplacetowork_co_ke: Logo already exists, skipping download.
# ✅ einhell_fi: Downloaded from Clearbit
# ✅ affidea_ro: Logo already exists, skipping download.
# ⚠️ kumon_com_pe: Clearbit 404, trying Google Favicon...
# ✅ kumon_com_pe: Downloaded from Google Favicon
# ✅ sitech_fi: Downloaded from Clearbit
# ✅ bosch-pt_com_cn: Downloaded from Clearbit
# ⚠️ aamcomcdonoughga_com: Clearbit 404, trying Google Favicon...
# ✅ aamcomcdonoughga_com: Downloaded from Google Favicon
# ✅ kia-poeschl-bensheim_de: Downloaded from Clearbit
# ✅ spitex-aarenord_ch: Downloaded from Clearbit
# ✅ gs1my_org: Downloaded from Clearbit
# ✅ mazda-autohaus-behrens-magdeburg-ottersleben_de: Logo already exists, skipping download.
# ✅ amnesty_org_ng: Logo already exists, skipping download.
# ⚠️ chicco_pl: Clearbit 404, trying Google Favicon...
# ❌ chicco_pl: No logo found on Google Favicon
# ✅ bbraun_co_za: Downloaded from Clearbit
# ✅ topdoctors_cl: Downloaded from Clearbit
# ✅ pingusenglishbd_com: Logo already exists, skipping download.
# ✅ wwfcz_org: Logo already exists, skipping download.
# ✅ flashbay_fi: Logo already exists, skipping download.
# ✅ wurth_sk: Downloaded from Clearbit
# ✅ grantthornton_co_im: Downloaded from Clearbit
# ✅ mazda_com_tr: Logo already exists, skipping download.
# ✅ aamcopuyallupwa_com: Downloaded from Clearbit
# ✅ nutriciavoorjou_nl: Logo already exists, skipping download.
# ✅ pragroup_se: Downloaded from Clearbit
# ✅ toyota_com_np: Downloaded from Clearbit
# ✅ santanderconsumer_fi: Downloaded from Clearbit
# ✅ cfmotoitaly_it: Downloaded from Clearbit
# ✅ daikin_eu: Downloaded from Clearbit
# ⚠️ lindt_com_mx: Clearbit 404, trying Google Favicon...
# ❌ lindt_com_mx: No logo found on Google Favicon
# ✅ exertisztorm_com: Downloaded from Clearbit
# ✅ honda-chateauroux_com: Downloaded from Clearbit
# ✅ vbh_com_es: Downloaded from Clearbit
# ✅ cimbbank_com_vn: Downloaded from Clearbit
# ✅ toyotakocaelikaya_com_tr: Logo already exists, skipping download.
# ✅ toyotamici_com_tr: Logo already exists, skipping download.
# ✅ mazda-bielskobiala-autogazda_pl: Logo already exists, skipping download.
# ✅ hyundaicentralsales_com: Downloaded from Clearbit
# ⚠️ aamcosanbernardinoca_com: Clearbit 404, trying Google Favicon...
# ✅ aamcosanbernardinoca_com: Downloaded from Google Favicon
# ✅ mazda-autohaus-tietje-holmb-wedel_de: Logo already exists, skipping download.
# ✅ plameco-rheinsieg_de: Logo already exists, skipping download.
# ✅ isover_ua: Logo already exists, skipping download.
# ✅ linde-healthcare_nl: Logo already exists, skipping download.
# ✅ nestle_com_py: Downloaded from Clearbit
# ⚠️ kumon_com_bo: Clearbit 404, trying Google Favicon...
# ✅ kumon_com_bo: Downloaded from Google Favicon
# ✅ reedglobal_com_tr: Logo already exists, skipping download.
# ✅ savethechildren_nl: Logo already exists, skipping download.
# ✅ ccusa_sk: Downloaded from Clearbit
# ✅ daikinchemicals_co_th: Logo already exists, skipping download.
# ✅ ampersand-world_com: Downloaded from Clearbit
# ✅ edenred_cl: Downloaded from Clearbit
# ✅ mazda-autohaus-brutschin-lenzkirch_de: Logo already exists, skipping download.
# ⚠️ freseniuskidneycare_au: Clearbit 404, trying Google Favicon...
# ✅ freseniuskidneycare_au: Downloaded from Google Favicon
# ✅ funiber_org_co: Downloaded from Clearbit
# ✅ intersport_com_au: Downloaded from Clearbit
# ✅ advantisengineering_com: Downloaded from Clearbit
# ✅ adra_nl: Logo already exists, skipping download.
# ✅ linde_ch: Downloaded from Clearbit
# ⚠️ enterprise_ae: Clearbit 404, trying Google Favicon...
# ✅ enterprise_ae: Downloaded from Google Favicon
# ⚠️ hps-guns_de: Clearbit 404, trying Google Favicon...
# ✅ hps-guns_de: Downloaded from Google Favicon
# ✅ gs1lt_org: Downloaded from Clearbit
# ✅ carglass_ee: Logo already exists, skipping download.
# ✅ amway_fr: Downloaded from Clearbit
# ✅ airbnb_am: Downloaded from Clearbit
# ✅ toyotaer_com_tr: Logo already exists, skipping download.
# ✅ mcdonalds_com_sg: Downloaded from Clearbit
# ✅ stampinup_uk: Downloaded from Clearbit
# ⚠️ bbraun_cn: Clearbit 404, trying Google Favicon...
# ❌ bbraun_cn: No logo found on Google Favicon
# ✅ aamcotulsa-harvard_com: Downloaded from Clearbit
# ✅ carlsjr_co_nz: Logo already exists, skipping download.
# ✅ toyotadefence_com: Downloaded from Clearbit
# ✅ nobleprog_co_th: Logo already exists, skipping download.
# ✅ msmode_lu: Downloaded from Clearbit
# ✅ rexel_ca: Downloaded from Clearbit
# ✅ drinkculligan_com: Downloaded from Clearbit
# ✅ amnesty_hu: Logo already exists, skipping download.
# ✅ bakertilly_lu: Logo already exists, skipping download.
# ✅ gjw-mv_de: Downloaded from Clearbit
# ✅ servier_bg: Logo already exists, skipping download.
# ✅ mazda_fi: Logo already exists, skipping download.
# ✅ nutricia_de: Logo already exists, skipping download.
# ✅ mazda-bcrmotors_ru: Logo already exists, skipping download.
# ✅ aamcomcallen_com: Downloaded from Clearbit
# ✅ portadoors_com: Downloaded from Clearbit
# ⚠️ mcdonalds-hh_de: Clearbit 404, trying Google Favicon...
# ❌ mcdonalds-hh_de: No logo found on Google Favicon
# ✅ synlab_com_cy: Logo already exists, skipping download.
# ✅ bakertilly_vg: Logo already exists, skipping download.
# ✅ mazda-autohaus-hohenfeld-dinslaken_de: Logo already exists, skipping download.
# ✅ subaruvilnius_lt: Logo already exists, skipping download.
# ✅ thelocal_fr: Downloaded from Clearbit
# ✅ avis-tahiti_com: Downloaded from Clearbit
# ✅ ebay_com_hk: Logo already exists, skipping download.
# ✅ medef-aura_fr: Downloaded from Clearbit
# ✅ bees-sport_nl: Downloaded from Clearbit
# ✅ spitex-wyland_ch: Downloaded from Clearbit
# ✅ nextbikeczech_com: Downloaded from Clearbit
# ✅ solatube_pt: Downloaded from Clearbit
# ⚠️ zkteco-ao_com: Clearbit 404, trying Google Favicon...
# ❌ zkteco-ao_com: No logo found on Google Favicon
# ✅ greatplacetowork_ch: Logo already exists, skipping download.
# ✅ renaultpuertovallarta_com_mx: Logo already exists, skipping download.
# ✅ toyotasud_ro: Logo already exists, skipping download.
# ✅ veolia_sk: Logo already exists, skipping download.
# ⚠️ skoda-nancy_fr: Clearbit 404, trying Google Favicon...
# ✅ skoda-nancy_fr: Downloaded from Google Favicon
# ✅ howdentiger_com: Downloaded from Clearbit
# ✅ thebodyshop_ee: Downloaded from Clearbit
# ✅ adra_sk: Downloaded from Clearbit
# ✅ mazda-autohaus-lommel-grettstadt_de: Logo already exists, skipping download.
# ✅ biothanesolutions_com: Logo already exists, skipping download.
# ✅ culliganallegan_com: Downloaded from Clearbit
# ✅ subaru_com_tr: Logo already exists, skipping download.
# ✅ toyota-marseille_com: Logo already exists, skipping download.
# ✅ hertz_com_do: Downloaded from Clearbit
# ⚠️ avon_co_mu: Clearbit 404, trying Google Favicon...
# ✅ avon_co_mu: Downloaded from Google Favicon
# ✅ ikea_ee: Logo already exists, skipping download.
# ✅ wwf_or_th: Logo already exists, skipping download.
# ✅ harigmfg_com: Downloaded from Clearbit
# ✅ toysrus_pt: Logo already exists, skipping download.
# ✅ actemium_us: Logo already exists, skipping download.
# ✅ mazda-autohaus-grasdanner-holzkirchen_de: Logo already exists, skipping download.
# ✅ aamcorandallstownmd_com: Downloaded from Clearbit
# ✅ budget-ireland_co_uk: Logo already exists, skipping download.
# ✅ shopee_vn: Downloaded from Clearbit
# ✅ toyotafocsani_ro: Logo already exists, skipping download.
# ✅ aamcocarync_com: Downloaded from Clearbit
# ✅ toysrus_com_sg: Logo already exists, skipping download.
# ✅ aliaxis_pl: Downloaded from Clearbit
# ✅ synlab_ec: Logo already exists, skipping download.
# ✅ ccusa_co_za: Downloaded from Clearbit
# ✅ aamcolawrencevillega_com: Downloaded from Clearbit
# ✅ mazda-autohaus-born-ludwigslust_de: Logo already exists, skipping download.
# ✅ savethechildren_ca: Logo already exists, skipping download.
#
# 🎉 ✅ All logos processed! Check 'logos_with_paths.csv' for results.
